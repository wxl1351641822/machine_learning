# %% [markdown]
# * 陈述算法在最坏情况下的时间复杂度和平均时间复杂度。各有什么实际意义？
#     * 最坏时间复杂度。在各种数据分布下的操作步数中最大的那一个，
#         * 确定算法的最长用时用户是否可以接受。（不会更坏了，是保证）
#         * 确定该程序是否可以满足实时要求？
#     * 平均时间复杂度。在各种数据分布下操作步数的平均值。
#         * 把握算法的难易程度。
#         * 比较算法优劣，以改进算法。
#     * 最坏情况下的时间复杂度称最坏时间复杂度。一般不特殊说明，论的时间复杂度均是最坏情况下的时间复杂度。
#         * 这样做的原因：是最坏情况下的时间复杂度是算法在任何输入实例上运行时间的上界，这就保证了算法的运行时间不会比任何长
#     * 平均时间复杂度是指所有可能的输入实例均以等概率出现的情况下，算法的期望运行时间。（实际中，通过运行一定数量的试验数据后取平均值估算得到）

# %% [markdown]
# * 阐述动态规划算法与贪心算法的区别，他们都有哪些优势和劣势？
#
#     * 都要求问题具有最优子结构性质
#
#     * 动态规划算法与分治法和贪心法类似，他也是将原问题，分成若干个更小的相似的子问题，并通过求解子问题产生一个全局最优解。
#     * 一种递推算法，均由局部最优解来推导全局最优解。
#
#     * 区别
#
#         * 贪心法：时，当前的选择，要依赖于已经做出的所有选择，但不依赖于有待于做出的选择和子问题，因此贪心法自顶向下的即从起点到终点一步步的做出的贪心选择。当然，如果当前的选择可能要依赖于子问题的解时，则难以通过局部的贪心策略达到全局最优解。做出的每步贪心决策都无法改变，每一步的最优解，一定包含上一步的最优解，而上一部步之前的最优解则不做保留。贪心算法所做出的选择你那于以往所做出的选择，但绝不依赖于将来的选择，这使得算法在编码和执行过程中都有一定的速度优势，贪心算法只是找局部最优解，不一定是全局最优解。。
#
#         * 分治法：时，由原问题分解出的各个子问题通常相互独立，即不包含公共的子问题。因此一旦递归地求出各子问题的解后，便可自下而上地将各个子问题的解合并成问题的解。如果各个子问题不是相互独立的，则分治法要做许多不必要的工作，重复的求解公共的子问题。
#
#         * 动态规划：允许原问题分解出的子问题之间相互依赖，每一个子问题只求解一次，并将结果保存起来，避免每次碰到此问题时都要重复求解。不同的子问题个数随着输入问题的规模呈多项式增长，因此动态规划算法通常只需要多项式时间，从而获得比较高的解题效率，但他需要计算之前的所有情况的花费，更加耗费空间。
#             * 依据什么性质设计（基本条件）
#                 * 最优子结构（一个最优化策略的子策略总是最优的
#                 * 子问题重叠（利用这个提高效率
# * 动态规划和分枝定界
#     * 动态规划算法将原问题划分为子问题求解
#     * 分枝定界问题是在整个解空间中宽度搜索最优解
#     * 动态规划效率高点
#
#
# 贪心算法和动态规划算法有什么共同点和区别？他们有哪些优势和劣势？
#
# 共同点动态规划和贪心算法都是一种递推算法，均由局部最优解来推导全局最优解。
#
# 区别
#
# 贪心算法中做出的每步贪心决策都无法改变，每一步的最优解，一定包含上一步的最优解，而上一部步之前的最优解则不做保留。
#
# 动态规划算法中全局最优解一定包含某个局部最优解，但不一定包含前一个局部最优解，且因此需要进入之前所有的最优解。
#
# 动态规划算法中利用子问题的重叠性质对每一个子问题只计算一次，将其解保存在一个表格中。不同的子问题个数随着输入问题的规模呈多项式增长，因此动态规划算法通常只需要多项式时间，从而获得比较高的解题效率，但他需要计算之前的所有情况的花费，更加耗费空间。
#
# 贪心算法所做出的选择你那于以往所做出的选择，但绝不依赖于将来的选择，这使得算法在编码和执行过程中都有一定的速度优势，贪心算法只是找局部最优解，不一定是全局最优解。。

# %% [markdown]
# * 阐述回溯算法与分支限界算法的共同点和不同点提高算法效率的关键是什么？
#
# |  | 回溯法 | 分支限界算法 |
# | --- | --- | --- |
# | 空间树的搜索方式。 | 深度优先搜索，  | 广度优先搜索或最小消耗优先搜索。 |
# | 存储节点的常用数据结构。 | 堆栈。| 队列或优先队列 |
# | 节点存储特性。| 活节点的所有可行子结构被遍历后才从栈中排出。 | 每个节点只有一次成为活节点的机会。 |
# | 常用应用。 | 找出满足约束条件的所有解。 | 找出满足约束条件的一个解或特定意义下的最优解。 |

# %% [markdown]
# 在对算法进行复杂性分析时，强调渐进复杂性的意义。
#
# 算法的复杂性是算法效率的度量，是评价算法优劣的重要依据。一个算法复杂性的高低体现在运行该算法所需要的计算机资源的多少上。所需的资源越多，我们就说该算法的复杂性越高，反之所需要的资源越低，则算法的复杂性越低。
#
# 简化算法复杂性分析的方法和步骤，即只考虑当问题规模足够大时，算法复杂性在渐进意义下的阶，与此简化的算法复杂度分析方法相配套。
#
# 问题复杂程度和规模的线性增长，导致时耗的增长和空间需求的增长对低效算法来说都是超线性的，绝非计算机速度和容量的线性增长所带来的时耗减少和存储空间的扩大所能抵消的。
#
# * 当问题规模n趋于无穷大时，影响算法效率的重要因素是复杂度函数主项，而其他因素仅使复杂度相差常数倍，使用渐进表达式，可以略去低阶项，留下影响更大的主项，更加简单。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 什么NPC问题，证明一个问题是NPC问题的步骤
#     * 所有NP问题均可在多项式时间内变换到该问题上。
#         1. 原问题是NP问题
#         2. 已知一个问题I是NPC问题
#         3. 原问题可经由I经多项式时间变换而来
